# %%
import pandas
from pandas import DataFrame
import pandas as pd
import read_data
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
dataframe = read_data.create_frame()
dataframe
# Out:
#        object_name          seq_name num_of_sequences sequence_len cycle  \
# 0           BRUMC1            BRUMC1                1            8
# 1           BRUMC2            BRUMC2                1            2     a
# 2           BRUMC3            BRUMC3                1            2     a
# 3           BRUMC4            BRUMC4                1            2     a
# 4           COLA02            COLA02                1            8
# ..             ...               ...              ...          ...   ...
# 250  MUNSA-0007688     MUNSA-0007688                1            8     0
# 251  MUNSA-0007686     MUNSA-0007686                1           10     0
# 252   HMV-63.54.12   HMV-63.54.12inf                2           16     0
# 253   HMV-63.54.12  HMV-63.54.12cent                2           16     0
# 254         COLA27            COLA27                1            6     a
#
#                                        sequence_values  scenes
# 0    [B.27.23.B.30, A.38, G.27.30, B.24.11, B.27.28...     [1]
# 1                            [E.17.48.3, B.29.23.B.25]    [14]
# 2                                    [B.29.35, B.24.5]    [13]
# 3                                   [B.24.11, B.29.35]    [14]
# 4    [B.24.11, B.31.28, A.6, B.24.28.7, A.38, B.29....  [1, 5]
# ..                                                 ...     ...
# 250  [B.24.10, B.27.25.B.30, A.36, B.24.28, B.24.11...     [9]
# 251  [A.37, B.29.25, A.37, B.29.25, A.37, B.29.25, ...    None
# 252  [E.31.47, B.29.25, A.19, B.31.25, E.31.47, B.2...    None
# 253  [B.29.25, A.19, B.31.25, A.17, B.29.25, A.19, ...    None
# 254  [B.24.28, A.1.47, H.24.28, E.31.47, C.24.3, B....    None
#
# [255 rows x 7 columns]

# %%
sequences = dataframe['sequence_values']
sequences
symbols_dict = dict()
all_symbols_set = set()
for seq in sequences:
    for index, symbol in enumerate(seq):
        if index > 0:
            if symbol not in symbols_dict.keys():
                symbols_dict[symbol] = dict()
                all_symbols_set.add(symbol)
            if seq[index-1] not in symbols_dict[symbol].keys():
                symbols_dict[symbol][seq[index-1]] = 0
                all_symbols_set.add(seq[index-1])
            symbols_dict[symbol][seq[index-1]] += 1
for symbol in symbols_dict.keys():
    print(f'{symbol}: {max(symbols_dict[symbol].items(), key=lambda pair: pair[1])}')

print(len(all_symbols_set))
# Out:
# A.38: ('B.27.30', 5)
# G.27.30: ('A.38', 1)
# B.24.11: ('G.29.52', 8)
# B.27.28.30.B.30: ('B.24.11', 1)
# A.4: ('C.29', 2)
# H.24.28: ('A.6', 6)
# B.24.12: ('A.38', 4)
# B.29.23.B.25: ('E.17.3', 9)
# B.24.5: ('B.29.35', 2)
# B.29.35: ('B.24.11', 4)
# B.31.28: ('B.24.11', 5)
# A.6: ('B.29.30', 8)
# B.24.28.7: ('A.6', 1)
# B.29.30.10: ('B.31.28.B.32', 2)
# E.31.20: ('B.29.30.10', 1)
# B.27.30: ('B.24.11', 12)
# C.24.1: ('B.24.28', 6)
# G.29.30.52: ('C.24.1', 2)
# A.36: ('B.27.30', 10)
# B.27.23: ('B.24.11', 2)
# B.29.23: ('A.6', 3)
# E.17: ('C.24.1', 5)
# C.29: ('A.1.16', 2)
# B.24.28: ('A.36', 3)
# G.29.52: ('A.6', 8)
# B.29.23.B.30: ('B.24.11', 2)
# B.24.25: ('C.24.1', 3)
# B.31.21: ('A.6', 4)
# E.17.3: ('B.29.25', 2)
# B.29.34: ('E.17.3', 1)
# B.29.30: ('A.38', 6)
# B.24.10.7: ('B.29.30', 1)
# B.29.25: ('A.37', 5)
# E.17.48.3: ('B.29.25', 1)
# B.29.23.25.B.25: ('E.17.3', 1)
# B.29.23.B.35: ('E.17.3', 2)
# B.31.28.30: ('E.17.3', 2)
# B.27.23.B.25: ('A.36', 1)
# H.31.22: ('E.31.14.47', 1)
# G.H.29.52: ('C.24.1', 1)
# A.12: ('B.27.30', 2)
# G.27: ('A.12', 1)
# C.24: ('B.27.30', 2)
# E.31.14.47: ('C.24', 1)
# B.27.23.B.30: ('A.36', 1)
# B.31.12: ('G.29.30.52', 2)
# G.29.51: ('A.38', 1)
# A.18: ('G.29.52', 2)
# B.27.30.10: ('A.18', 1)
# B.31.11: ('B.29.30', 3)
# A.1.16: ('B.27.30', 3)
# A.44: ('A.1.16', 2)
# A.11: ('A.38', 1)
# 0: ('0', 6)
# I.31.1.3: ('B.24.11', 1)
# E.17.48: ('B.27.23', 1)
# A.13: ('B.24.28', 3)
# B.29.23.10: ('A.1.16', 1)
# E.31.22: ('B.27.30', 3)
# B.31.21.R: ('A.6', 1)
# B.24.28.10: ('B.31.28', 2)
# B.31.5: ('A.38', 1)
# E.31.28.47: ('A.38', 1)
# B.27.23.23: ('B.24.11', 1)
# A.19.13: ('C.29', 1)
# A.1: ('G.29.52', 2)
# B.27.30.B.114: ('B.24.11', 1)
# B.29.25.B.23: ('A.250.47.48', 1)
# A.247.R: ('E.17', 1)
# B.27.30.B.23: ('B.24.11', 1)
# B.24.11.7: ('B.29.30', 4)
# C.27: ('B.24.11', 2)
# B.31.28.30.B.25: ('C.24.1', 1)
# A.17: ('B.31.25', 6)
# B.31.28.B.32: ('A.17', 1)
# B.31.28.B.25: ('A.1.48', 2)
# B.31.23.23.B.25.8: ('B.31.28.B.25', 1)
# G.27.30.52: ('B.24.12', 1)
# B.29.115: ('B.24.25', 1)
# E.31.14: ('C.24.1', 2)
# B.29.35.B.25: ('B.24.11.7', 2)
# B.24.23.28.10: ('A.17.3', 2)
# B.29.23.28: ('B.24.23.28.10', 2)
# A.17.3: ('B.29.23.28', 1)
# B.29.25.B.35: ('E.17', 1)
# B.29.30.11: ('B.24.11', 1)
# B.24.23.28.9: ('E.17', 1)
# A.245: ('C.24.1', 1)
# B.29.25.B.30: ('E.17', 2)
# B.27.25.B.30: ('A.44', 2)
# A.37: ('B.29.25', 4)
# B.29.25.29: ('E.17', 1)
# A.6.17: ('B.31.21', 1)
# B.24.23.B.28.30: ('H.24.28', 1)
# C.24.1.3: ('B.29.25', 1)
# B.24.35: ('C.24.1.3', 1)
# B.24.28.R: ('E.17', 3)
# B.24.10: ('E.31.22', 2)
# B.31.25: ('A.19', 3)
# A.2.17: ('C.24.1', 2)
# B.24.28.30.7: ('G.29.30.52', 1)
# B.24.28.30: ('B.50.10', 2)
# A.1.40: ('B.24.28.30', 1)
# A.33.3: ('B.24.28.30', 1)
# C.110: ('A.37', 1)
# B.50.10: ('A.17', 2)
# B.31.246: ('B.50.10', 1)
# E.1.47: ('B.31.246', 2)
# C.24.47.1: ('A.6', 3)
# I.31.17: ('B.31.28.B.32', 2)
# B.29.23.23.B.30: ('A.36', 1)
# B.50.R: ('A.2.47', 1)
# C.24.2: ('E.17', 2)
# B.31.R: ('C.24.2', 2)
# B.29.10: ('B.31.R', 2)
# A.19: ('B.29.25', 6)
# A.1.3: ('B.24.28', 2)
# B.31.25.B.28.30: ('B.29.25', 1)
# A.4.47: ('0', 1)
# K.102.51: ('C.24.1', 1)
# A.2: ('B.29.23', 1)
# A.2.16: ('A.17', 1)
# G.29: ('A.38', 2)
# A.244: ('B.24.28.7', 1)
# B.29.30.B.25: ('C.24.1', 1)
# A.19.R: ('A.37', 2)
# E.17.47: ('B.24.28.R', 2)
# A.17.47: ('B.24.28.R', 1)
# ?: ('0', 1)
# C.24.28: ('0', 1)
# A.18.17: ('A.19', 1)
# C.24.15: ('0', 1)
# A.19.10: ('B.24.25', 1)
# A.18.47: ('A.19.10', 1)
# H.24.28.7: ('A.17', 2)
# C.24.2.3: ('H.24.28.9', 1)
# B.24.12.R: ('G.29.30.52', 2)
# B.29.25.R: ('B.24.12.R', 2)
# B.29: ('E.17', 2)
# B.27: ('0', 2)
# A.242: ('B.29.23.B.30', 1)
# K.102.53: ('A.242', 1)
# C.111: ('A.18', 1)
# C.24.47: ('A.1', 1)
# B.31.28.R: ('A.38', 1)
# A.39: ('C.24.47.1', 2)
# K.103.53: ('A.13', 3)
# B.24.25.R: ('A.4', 1)
# A.1.48: ('A.38', 2)
# B.24.25.B.28.30: ('I.24.32', 2)
# I.24.32: ('C.24.1', 1)
# B.24.28.30.B.25: ('I.24.32', 1)
# E.31.47: ('B.31.25', 2)
# E.31.113: ('A.19', 4)
# A.1.47: ('B.24.28', 1)
# C.24.3: ('E.31.47', 1)
# 170

# %%
symbols_data = np.zeros(shape=(len(all_symbols_set), len(all_symbols_set)))
symbols_indexes = dict([(symbol, index) for index, symbol in enumerate(all_symbols_set)])
for symbol, values in symbols_dict.items():
    for symbol_, value in values.items():
        symbols_data[symbols_indexes[symbol]][symbols_indexes[symbol_]] = value
df = DataFrame(symbols_data, index=list(all_symbols_set), columns=list(all_symbols_set))

plt.figure(figsize=(20, 16))
plt.imshow(df, cmap='viridis', interpolation='nearest')
plt.colorbar(label='How many times each signs is after another')
plt.title('Frequency of occurrence of characters following each other')
plt.xticks(np.arange(len(df.columns)), df.columns, rotation=90, fontsize=5)
plt.yticks(np.arange(len(df.index)), df.index, fontsize=5)
plt.show()

# %%
def filter_values(x):
    if x > 5:
        return x
    else:
        return None

filtered_df = df.applymap(filter_values)

# Usuwanie wartości None
filtered_df.dropna(axis=0, how='all', inplace=True)
filtered_df.dropna(axis=1, how='all', inplace=True)

print(filtered_df)
# Out:
#               B.31.25  B.29.25  A.6  A.38  E.17.3  B.29.23    0  E.17  \
# B.29.23.B.25      NaN      NaN  NaN   NaN     9.0      NaN  NaN   6.0
# A.6               NaN      NaN  NaN   NaN     NaN      NaN  NaN   NaN
# H.24.28           NaN      NaN  6.0   NaN     NaN      NaN  NaN   NaN
# 0                 NaN      NaN  NaN   NaN     NaN      NaN  6.0   NaN
# A.36              NaN      NaN  NaN   NaN     NaN      NaN  NaN   NaN
# A.19              NaN      6.0  NaN   NaN     NaN      NaN  NaN   NaN
# B.29.30           NaN      NaN  NaN   6.0     NaN      NaN  NaN   NaN
# B.27.30           NaN      NaN  NaN   9.0     NaN      NaN  NaN   NaN
# B.24.11           NaN      NaN  6.0   NaN     NaN      8.0  NaN   NaN
# G.29.52           NaN      NaN  8.0   NaN     NaN      NaN  NaN   NaN
# C.24.1            NaN      NaN  NaN   NaN     NaN      NaN  NaN   NaN
# A.17              6.0      NaN  NaN   NaN     NaN      NaN  NaN   NaN
#
#               B.24.28  B.29.30  B.27.30  B.24.11  G.29.52
# B.29.23.B.25      NaN      NaN      NaN      6.0      NaN
# A.6               NaN      8.0      NaN      NaN      NaN
# H.24.28           NaN      NaN      NaN      NaN      NaN
# 0                 NaN      NaN      NaN      NaN      NaN
# A.36              NaN      NaN     10.0      NaN      NaN
# A.19              NaN      NaN      NaN      NaN      NaN
# B.29.30           NaN      NaN      NaN      NaN      NaN
# B.27.30           NaN      NaN      NaN     12.0      NaN
# B.24.11           NaN      NaN      6.0      NaN      8.0
# G.29.52           NaN      NaN      NaN      NaN      NaN
# C.24.1            6.0      NaN      NaN      NaN      NaN
# A.17              NaN      NaN      NaN      NaN      NaN
# C:\Users\zuzaw\AppData\Local\Temp\ipykernel_11936\2423883208.py:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   filtered_df = df.applymap(filter_values)

# %%
plt.figure(figsize=(20, 16))
plt.imshow(filtered_df, cmap='viridis', interpolation='nearest')
plt.colorbar(label='How many times each signs is after another')
plt.title('Frequency of occurrence of characters following each other')
plt.xticks(np.arange(len(filtered_df.columns)), filtered_df.columns, rotation=90, fontsize=5)
plt.yticks(np.arange(len(filtered_df.index)), filtered_df.index, fontsize=5)
plt.show()
